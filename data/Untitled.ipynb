# %%
import pandas as pd
kk = pd.read_csv('water_data.csv')

# %%
index_of_timestamp = kk[kk['Time'] == '2023-07-07 01:00:00'].index[0]

# %%
index_of_timestamp
# Out:
# 10368

# %%
kk.iloc[10368:, :]
# Out:
#                       Time  MHC_Water_Level  MH_Water_Level  PG_Water_Level  \
# 10368  2023-07-07 01:00:00             1.73            0.55            1.27
# 10369  2023-07-07 02:00:00             1.72            0.54            1.26
# 10370  2023-07-07 03:00:00             1.71            0.54            1.25
# 10371  2023-07-07 04:00:00             1.69            0.54            1.25
# 10372  2023-07-07 05:00:00             1.69            0.53            1.24
# ...                    ...              ...             ...             ...
# 12951  2023-10-22 16:00:00             1.28            0.05            0.95
# 12952  2023-10-22 17:00:00             1.28            0.06            0.95
# 12953  2023-10-22 18:00:00             1.28            0.06            0.95
# 12954  2023-10-22 19:00:00             1.28            0.06            0.95
# 12955  2023-10-22 20:00:00             1.28            0.06            0.95
#
#        HH_Water_Level  GG_Water_Level
# ...
